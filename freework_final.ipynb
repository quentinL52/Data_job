# %% [markdown]
# <a href="https://colab.research.google.com/github/quentinL52/Data_job/blob/anissa/freework_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## librairie

# %%
import pandas as pd
import numpy as np
import requests
import hashlib

# import regex
import re

# import scrapping
from bs4 import BeautifulSoup
from urllib.request import urlopen


from pprint import pprint

# import ID
import uuid

# import pour voir l'avancement du chargement
from tqdm import tqdm

# import pour base de donnée
import sqlite3

# %% [markdown]
# ## Freework  File

# %%
def api_freework():
  headers = {
      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
      'Accept': 'application/json',

  }

  l_df = []
  for page in tqdm(range(1,23)):

      url = f"https://www.free-work.com/api/job_postings?page={page}&itemsPerPage=16&searchKeywords=data+analyste"
      response = requests.get(url, headers=headers)
      if response.status_code == 200:
          data = response.json()  # Si la réponse est en JSON
          df = pd.DataFrame(data)
          l_df.append(df)
      else:
          pprint(f"Échec de la requête avec le statut: {response.status_code}")


  df = pd.concat(l_df)
  return df

df_all = api_freework()
# Out:
# 100%|██████████| 22/22 [00:24<00:00,  1.12s/it]

# %%
def clean_data(df):
# réitialisation de l'index
  df =df.reset_index(drop=True)

# supprimer colonne
  colonne_a_supprimer = ['startsAt','minAnnualSalary','maxAnnualSalary','applicationContact','applicationUrl','modifiedByUserAt','annualSalary','status','published','renewable','applicationType','createdAt','publishedAt','expiredAt']
  df = df.drop(columns=colonne_a_supprimer)

# creer une colonne pr l'origine de la données
  df['site_annonce']= 'freework'

# créer colonne lien
  df['lien'] = "https://www.free-work.com/fr/tech-it/analyste/job-mission/" + df['slug']

# Remplacer  par "€" dans la colonne 'colonne'
  df['currency'] = '€'

# remplacer les nan par inconnu dans company description
  for c  in ['remoteMode','candidateProfile','companyDescription'] :
    df[c] = df[c].fillna("aucun")

# Remplacer "Expert" par "senior" dans la colonne 'experienceLevel'
  df['experienceLevel'] = df['experienceLevel'].replace('expert', 'senior', regex=False)


# afficher les annonces commençant par data, business
  keywords = 'data|Data|Business|business|💼|Data Project Manager|Data scientist|PO DATA|Data Engineer|DATA engineer|Senior Data|Consultant Data|Consultant BI|Business Intelligence|DATA ENGINEER|'
  df = df[df['title'].str.contains(keywords, regex=True)]

#recuperer que les freelance
  df['contracts'] = df['contracts'].str.join(',')
  df = df[df.contracts.str.contains('contractor', na = False)]

# réitialisation de l'index
  df=df.reset_index(drop=True)

# extraire skills
  df['skills'] = df['skills'].apply(lambda list_dico_skill :   [dico['name']   for dico in list_dico_skill] )
  df['softSkills'] = df['softSkills'].apply(lambda list_dico_skill :   [dico['name']   for dico in list_dico_skill] )

# extraire location
  def extract_location(row):
    loc  = row['location']
    return loc['country'] , loc['adminLevel1'],  loc['adminLevel2'], loc['postalCode'],loc['label'], str(loc['longitude']), str(loc['latitude'])

  result = df.apply(extract_location, axis = 1, result_type='expand')

# Renommer les colonnes
  result.columns = ['country', 'region', 'departement', 'postalCode','label','longitude', 'latitude']

# Joindre le résultat à la dataframe d'origine
  df = pd.concat([df, result], axis=1)

# extraire company
  def extract_compagny(row):
    loc  = row['company']
    try :
      return loc['description'] , loc['logo']['medium'],  loc['name'].lower()
    except :

      return loc['description'] , loc['logo'],  loc['name'].lower()

  result_compagny = df.apply(extract_compagny, axis = 1, result_type='expand')

# Renommer les colonnes
  result_compagny.columns = ['description', 'logo', 'name']

# Joindre le résultat à la dataframe d'origine
  df= pd.concat([df, result_compagny], axis=1)

# mettre durationValue en int
  df['durationValue'] = df['durationValue'].astype(int)

# calcul de la moyenne salaire avec création de la colonne
  df['averageDailySalary'] = df[['minDailySalary', 'maxDailySalary']].mean(axis=1)

# Convertir la colonne averageDailySalary de float en int
  df['averageDailySalary'] = df['averageDailySalary'].astype(int)

# convertir update en date .dt.strftime('%d-%m-%Y')
  df['updatedAt'] = pd.to_datetime(df['updatedAt'])  # Conversion en datetime
  df["updatedAt"] = df["updatedAt"].dt.date  # Extraire la date

# Normalisation
  dico_renommage = {
        'site_annonce': 'site_annonce',
        'name': 'entreprise',
        'updatedAt': 'publication',
        'title': 'poste',
        'experienceLevel': 'experience',
        'contracts': 'contrat',
        'durationValue': 'valeur_duree_contrat',
        'durationPeriod': 'type_duree_contrat',
        'remoteMode': 'teletravail',
        'averageDailySalary': 'valeur salaire',
        'currency': 'devise_salaire',
        'companyDescription': 'competences',
        'candidateProfile': 'profil',
        'description': 'description',
        'label': 'ville',
    }

  df = df.rename(columns=dico_renommage)

# Remplacer "none" par "aucun" et traduction des mots dans la colonne 'teletravail'
  df['teletravail'] = df['teletravail'].replace('none', 'aucun', regex=False)
  df['teletravail'] = df['teletravail'].replace('partial', 'partiel', regex=False)
  df['teletravail'] = df['teletravail'].replace('full', 'total', regex=False)


# traduction colonne experience :
  df['experience'] = df['experience'].replace('intermediate', 'intermediaire', regex=False)

# traduction colonne contrat :
  df['contrat'] = df['contrat'].replace('contractor', 'freelance', regex=False)
  df['contrat'] = df['contrat'].replace('contractor,permanent', 'freelance,cdi', regex=False)
  df['contrat'] = df['contrat'].replace('permanent,contractor', 'cdi,freelance', regex=False)

# traduction colonne type_duree_contrat:
  df['type_duree_contrat'] = df['type_duree_contrat'].replace('year', 'annee', regex=False)
  df['type_duree_contrat'] = df['type_duree_contrat'].replace('month', 'mois', regex=False)
  df['type_duree_contrat'] = df['type_duree_contrat'].replace('day', 'jour', regex=False)


# Convertir les colonnes  en lower
  df[['poste', 'teletravail','competences','profil','description']] = df[['poste', 'teletravail','competences','profil','description']].apply(lambda x: x.str.lower())
  df['ville'] = df['ville'].str.lower()


# Créer une colonne id avec UUID
  #df['id'] = df[['entreprise', 'poste', 'contrat', 'ville']].apply(lambda _: uuid.uuid4(), axis=1)

#  créer un id
  def generate_id(row, columns):
    # Concaténer les valeurs des colonnes sélectionnées en une seule chaîne
    value = ''.join(str(row[col]) for col in columns)
    # Générer un hachage MD5 de cette chaîne
    return hashlib.md5(value.encode()).hexdigest()

  df['id'] = df.apply(lambda row: generate_id(row, ["entreprise", "poste" , "contrat" , "ville"]), axis=1)

# Réorganiser les colonnes selon l'ordre souhaité
  colonnes_finales = [
        'id', 'site_annonce', 'entreprise', 'publication', 'poste', 'experience',
        'contrat', 'valeur_duree_contrat', 'type_duree_contrat', 'teletravail',
        'valeur salaire', 'devise_salaire', 'competences', 'profil', 'description', 'ville','lien'
    ]

# Vérifier et supprimer les colonnes en double
  df = df.loc[:,~df.columns.duplicated()]

# Reorganiser les colonnes
  df = df.reindex(columns=colonnes_finales)


# Fonction pour enlever toutes les balises HTML dans les colonnes de mon dataframe grâce à BeautifulSoup
  df['profil'] = df['profil'].apply(lambda x: BeautifulSoup(x, 'html.parser').text)
  df['competences'] = df['competences'].apply(lambda x: BeautifulSoup(x, 'html.parser').text)
  df['description'] = df['description'].apply(lambda x: BeautifulSoup(x, 'html.parser').text)


  # save as csv
  df.to_csv("freeworker.csv", index=False)
  return df

freework_clean = clean_data(df_all)

print(freework_clean.head(50).to_markdown())
# Out:
# |    | id                               | site_annonce   | entreprise                                       | publication   | poste                                                       | experience    | contrat       |   valeur_duree_contrat | type_duree_contrat   | teletravail   |   valeur salaire | devise_salaire   | competences                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 | profil                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# |---:|:---------------------------------|:---------------|:-------------------------------------------------|:--------------|:------------------------------------------------------------|:--------------|:--------------|-----------------------:|:---------------------|:--------------|-----------------:|:-----------------|:------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |  0 | 71c003fcc9944de05a8ad3d8e72944d7 | freework       | red commerce - the global sap solutions provider | 2024-06-21    | data analyste qlik sense                                    | intermediaire | freelance     |                      3 | mois                 | partiel       |              275 | €                | développer et maintenir des tableaux de bord interactifs avec qlik sense.analyser des ensembles de données complexes pour fournir des insights pertinents.automatiser les processus de reporting et garantir l'exactitude des données.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      | expérience prouvée en tant que data analyst avec qlik sense.maîtrise des techniques de visualisation de données et des outils bi.compétences avancées en sql et en manipulation de données.excellentes capacités d'analyse et de résolution de problèmes.bonnes compétences en communication et capacité à travailler en équipe.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# |  1 | 547fc7c8bbe53de2d8a1b6f9f3be8e41 | freework       | gradiant                                         | 2024-06-21    | data analyst /business analyst                              | senior        | freelance,cdi |                      1 | annee                | partiel       |              305 | €                | mission de longue durée au sein de la data factory composé de 15 personnes, intervention au sein du projet de refonte de la plateform data. télétravail 2 jours par semaine.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                | - posséder une expérience significative de plus de 5 ans en tant que data analyst avec un niveau avancé en sql.- avoir une expérience dans un environnement de données digitales (plans de tracking, outils de web analytics comme piano/ga cdp).- connaître les services aws, notamment athéna.- avoir une expérience en tant que business analyst, démontrant une bonne capacité de compréhension des besoins métiers.- démontrer de solides compétences en analyse et en résolution de problèmes.- avoir des connaissances en modélisation décisionnelle.- excellente capacité de restitution des analyses, tant à l'écrit qu'à l'oral.- capacité à travailler efficacement en équipe et à communiquer clairement ses idées et conclusions.- excellentes compétences relationnelles.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# |  2 | cc94cb3203dc23945a2f94ca497b8b8f | freework       | amd blue                                         | 2024-06-21    | data analyst supply chain                                   | senior        | freelance,cdi |                      1 | annee                | partiel       |              550 | €                | mission en régie via amd blue datasecteur d’activité : retaillieu :  parisdéplacements possibles à : lilletélétravail :  partieldurée : 3 ansdémarrage possible : asap                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      | ø  vous êtes diplômé(e) d'une école d’ingénieur ou d’un master dans un domaine lié à la data et à l’informatiqueø  vous avez minimum 5 ans d’expériences professionnelles en tant que data analystø  vous avez un bon niveau en anglais à l’oral comme à l’écritø  vous êtes passionné(e) par la dataø  compétences et connaissances indispensable :o   maîtrise de python et sql comme langages de programmation est indispensableo   maîtrise des librairies python (numpy, pandas, polars) et de librairies de visualisation (matplotlib, plotly, ..)o   maîtrise des méthodes statistiques de bases (analyses descriptives, acp, classifications, échantillonnage, tests statistiques)o   expérience avec les modèles prédictifs et comment évaluer leur efficacitéo   maîtrise des outils de développement : git, github, ci/cd, vscode/pycharm, terminalo   des fortes compétences en visualisation de données (tableau ou similaire)o   expérience avec databrickso   maitrise d’aws                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# |  3 | a7a7d83653e8dc3fd367fbe8ce47e4b4 | freework       | visian                                           | 2024-06-21    | business analyst data                                       | senior        | freelance,cdi |                      1 | annee                | partiel       |              360 | €                | visian est une société de conseil spécialisée autour de l'innovation, la conception produit et la data.dans un marché où les enjeux de recrutement sont clés et où le nombre de freelances est en constante augmentation, visian a créé une entité dédiée au recrutement de freelances experts du digital et d’it.dans le cadre de ses projets, nous recherchons un profil business analyst suffisamment expérimenté avec une compétence data.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              | un profil ba orienté data est recherché ; il est dès lors nécessaire :- d'avoir un bon niveau de communication oral et écrit, afin d’expliquer les enjeux & regles de gestion aux interlocuteurs techniques et inversement avec la remontée des impératifs et possibilités techniques.- d'être à l'aise dans l'exploration des donnéesle périmètre actuel correspond aux domaines facturation, contrat, offre & prix.stack technique :jira, confluence, slack, teams,techno : aws, python, sql, spark, databricks.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# |  4 | c7382f2d7bd2d679437538f3efb6294a | freework       | absis conseil                                    | 2024-06-21    | data analyst - sas, python, power bi                        | senior        | freelance     |                      2 | annee                | partiel       |              615 | €                | pré-requis:bac+5 ecole d'ingénieur ou équivalentexpérience en tant que data analyst (plus de 7 ans d'expérience)compétences avancées en sql et maitrise de sas, python et power biconnaissance des technologies azurecompétences analytiques et capacité à interpréter des données complexesexpérience dans au moins un projet agilevous avez idéalement une expé en assurance (prévoyance, santé)  anglais : courant                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       | pré-requis:bac+5 ecole d'ingénieur ou équivalentexpérience en tant que data analyst (plus de 7 ans d'expérience)compétences avancées en sql et maitrise de sas, python et power biconnaissance des technologies azurecompétences analytiques et capacité à interpréter des données complexesexpérience dans au moins un projet agilevous avez idéalement une expé en assurance (prévoyance, santé)  anglais : courant                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# |  5 | 2ae08d1962c016370412675bf8ede290 | freework       | visian                                           | 2024-06-21    | data analyst                                                | senior        | freelance     |                      1 | annee                | partiel       |              350 | €                | visian est une société de conseil spécialisée autour de l'innovation, la conception produit et la data.dans un marché où les enjeux de recrutement sont clés et où le nombre de freelances est en constante augmentation, visian a créé une entité dédiée au recrutement de freelances experts du digital et d’it.dans le cadre de ses projets, nous recherchons un data analyst.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           | ✓compétences  appuyées  sur  la  bi  en  particulier  sur  la  partie  data  management  (sql,  etl, ordonnanceur, etc.)✓expérience  dans  la  mise  en place  de  flux,  l’objectif  étant  de  pouvoir  mettre  en  place  et ordonnancer des traitements pour calculer et stocker des agrégats✓aptitudes relationnelles ainsi que de bonnes qualités rédactionnelles, le consultant doit être en capacité de synthétiser et vulgariser son propos✓autonome,  méthodique  et  organisé,  il  sait  parfaitement  travailler  en  équipe,  et  présente  de bonnes capacités d’analyse et de résolution de problèmes complexesstack technique : ✓sql(teradata)✓etl (informatica)✓ordonnanceur (vtom, shell)livrables : ✓documentation (exigences logiciels, standards et bonnes pratiques)✓exigences fonctionnelles✓guides utilisateurs✓rapport de test✓spécifications fonctionnelle                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# |  6 | c4158189d2ec02e373cd63c72089e2fe | freework       | cat-amania                                       | 2024-06-21    | data analyst                                                | senior        | freelance     |                     45 | jour                 | partiel       |              340 | €                | sur le site de chartres, des déplacements ponctuels sont possibles sur les autres sites du groupe.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          | -           bi : sql server, ssis, ssas, ssrs, power bi, t-sql, dax, mdx, azure data lake, azure sql database, azure data factory,azure databricks, machine learning -           big data : scala, apache spark, apache hadoop, elasticsearch -           sgbd : oracle, sql server, cassandra, hbase, mongodb devops : git, jenkins, docker -           systèmes d’exploitation : unix, linux (ubuntu), windows -           méthodologies : scrum, agile                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# |  7 | 26258f05a7aa1b4b0d0af7d5f5522485 | freework       | skiils                                           | 2024-06-21    | data analyst senior                                         | intermediaire | freelance,cdi |                      1 | annee                | partiel       |             1710 | €                | environnement de travail :·        environnement flexible et convivial.·        mission hybride avec une présence au bureau entre une à deux fois par semaine.ce poste offre une opportunité unique de contribuer à des projets data innovants dans un environnement dynamique. si vous êtes passionné par la gestion de produits data et possédez les compétences requises, nous serions ravis de vous rencontrer !                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        | profil recherché :·        minimum 5 ans d'expérience en tant que data analyst·        solides compétences techniques, notamment en slq et python·        maîtrise des environnements cloud, en particulier google cloud provider (gcp)·        un première expérience dans sur des projets de promotioncompétences requises :·        excellentes compétences en communication et collaboration pour travailler efficacement avec des équipes diversifiées·        capacité à gérer des projets complexes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# |  8 | 6ad00cf544702561767d1e4ffc6a0639 | freework       | visian                                           | 2024-06-21    | data analyst - confirmé (h/f)                               | intermediaire | freelance,cdi |                      2 | annee                | partiel       |              350 | €                | les compétences requises pour assumer pleinement ce rôle sont :une maîtrise technique en etl ssis (niveau expert), en pl/sql, azure (data factory).sens du service, du résultat et de la satisfaction utilisateur.esprit d’équipe.réactivité liée au monde de la production.bon relationnel.sérieux, rigueur et curiosité.maitrise de la communication orale et écrite.capacité à synthétiser l’information par écrit.des connaissances du monde bancaire et particulièrement de la production seront un plus.power bi - confirmé - impératifssis - confirmé - impératifsql - confirmé - impératifdata factory / sql azure - junior - souhaitableconnaissances linguistiques :anglais lu, écrit (impératif)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 | les compétences requises pour assumer pleinement ce rôle sont :une maîtrise technique en etl ssis (niveau expert), en pl/sql, azure (data factory).sens du service, du résultat et de la satisfaction utilisateur.esprit d’équipe.réactivité liée au monde de la production.bon relationnel.sérieux, rigueur et curiosité.maitrise de la communication orale et écrite.capacité à synthétiser l’information par écrit.des connaissances du monde bancaire et particulièrement de la production seront un plus.power bi - confirmé - impératifssis - confirmé - impératifsql - confirmé - impératifdata factory / sql azure - junior - souhaitableconnaissances linguistiques :anglais lu, écrit (impératif)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# ...
# | 47 | f3ac01eb2042d44b07af87598f455e4d | freework       | cherry pick                                      | 2024-06-20    | lead data analyst                                           | senior        | freelance     |                     12 | mois                 | partiel       |              575 | €                | aucun                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       | compétences et qualités attendues :- vous justifiez d’une expérience d'au moins 10-15 ans dans l'analyse de données et la connaissance client- vous avez une forté appétence business et avez déjà été responsable d'une équipe de data analyst (idéalement dans une environnement média / telecom)- vous avez développé un expertise pour l’analyse des données au service de prises de décisions business- vous êtes capable de maintenir et communiquer largement sur une roadmap d'équipe- vous savez concevoir, planifier et assurer le suivi de projets data- vous collaborez efficacement avec diverses parties prenantes- vous êtes autonome, curieux et rigoureux- vous êtes capable de communiquer efficacement en anglais                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# | 48 | 8af17f1e151f94a4997caff5f5da940d | freework       | celad                                            | 2024-06-21    | consultant power b.i power platform                         | intermediaire | freelance     |                     12 | mois                 | partiel       |              450 | €                | • restituer les données de l'entreprise sous forme de tableaux de bord, de graphiques, de cubes olap pour faciliter les choix stratégiques de la direction• comprendre l’attendu en terme de reporting• collecter et stocker les données (extraction) puis les distribuer et les exploiter (restitution)• tester les différentes restitutions (cubes olap, tableaux de bord, reporting)• intégrer et mettre en production le développement• assurer une maintenance• mise en œuvre de socles/applications, datamanagement & business intelligence/analytics• migration d'un outil bi• mise en œuvre d'applications analytiques sous powerbi ou autres (e.g. analyse des dépenses, cartographie et optimisation des immeubles, ...)activités et tâches :• le pilotage et l’organisation des phases de migration de données (coordonner les travaux de migration)• l’étude des modèles de données source et destination• l’élaboration des fichiers de mapping (source / destination). ainsi que les différents fichiers de spécification• la stratégie de migration (etl)• la validation des scripts d'extraction et transformation• la prise en charge du plan de réversibilité des données• conception et réalisation de modèles de données et cubes ssas• conception dashboard powerbi (en proximité avec les métiers) et réalisation (mode import, direct query, live query)• développement de dashboards tableau, gestion des bases de données type sql, gestion des etls type informatica cloud, récupération ou le plug de données salesforce                                                                                                                                                                                                                                                                                                         | de formation supérieure bac+ 5 (ou expérience équivalente) avec une expérience professionnellede 5 ans et plus.compétences techniques :• power bi (desktop & service)• power platform,• business objects bi4,• oracle pl/sql,• git.compétences fonctionnelles• compréhension des enjeux métiers et businesscompétences humaines :• capacités de communication/vulgarisation/synthèse• capacités d’adaptationétat d’esprit :• sens du service• esprit d’équipe• curiosité• agilité d'esprit                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# | 49 | 6f55c54d1d5d558cf967df0efaff1a04 | freework       | spi informatique                                 | 2024-06-21    | product owner data / vie                                    | senior        | freelance     |                    126 | jour                 | partiel       |              545 | €                | aucun                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       | le profil devra disposer des compétences suivantes:data est un prérequisvie (métier) est un prérequisanalyses de données est un prérequispenelop est un apprécié                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...

# %%
freework_clean['lien'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## import .db

# %%
# Enregistrer un dataframe dans un fichier .db (fichier base de données)


def db_file_storage(db_name, table_name, df):

    # Connexion ou création du fichier .db
    conn = sqlite3.connect(f"{db_name}.db")

    # Enregistrer le DataFrame dans le fichier
    df.to_sql(name=table_name, con=conn, if_exists='append', index=False)

    # Fermer la connexion
    conn.close()

# %%
db_file_storage("freework","df_clean",freework_clean)

# %%
freework_clean.head()
# Out:
#                                  id site_annonce  \
# 0  71c003fcc9944de05a8ad3d8e72944d7     freework
# 1  547fc7c8bbe53de2d8a1b6f9f3be8e41     freework
# 2  cc94cb3203dc23945a2f94ca497b8b8f     freework
# 3  a7a7d83653e8dc3fd367fbe8ce47e4b4     freework
# 4  c7382f2d7bd2d679437538f3efb6294a     freework
#
#                                          entreprise publication  \
# 0  red commerce - the global sap solutions provider  2024-06-21
# 1                                          gradiant  2024-06-21
# 2                                          amd blue  2024-06-21
# 3                                            visian  2024-06-21
# 4                                     absis conseil  2024-06-21
#
#                                    poste     experience        contrat  \
# 0              data analyste qlik sense   intermediaire      freelance
# 1         data analyst /business analyst         senior  freelance,cdi
# 2              data analyst supply chain         senior  freelance,cdi
# 3                  business analyst data         senior  freelance,cdi
# 4  data analyst - sas, python, power bi          senior      freelance
#
#    valeur_duree_contrat type_duree_contrat teletravail  valeur salaire  \
# 0                     3               mois     partiel             275
# 1                     1              annee     partiel             305
# 2                     1              annee     partiel             550
# 3                     1              annee     partiel             360
# 4                     2              annee     partiel             615
#
#   devise_salaire                                        competences  \
# 0              €  développer et maintenir des tableaux de bord i...
# 1              €  mission de longue durée au sein de la data fac...
# 2              €  mission en régie via amd blue datasecteur d’ac...
# 3              €  visian est une société de conseil spécialisée ...
# 4              €  pré-requis:bac+5 ecole d'ingénieur ou équivale...
#
#                                               profil  \
# 0  expérience prouvée en tant que data analyst av...
# 1  - posséder une expérience significative de plu...
# 2  ø  vous êtes diplômé(e) d'une école d’ingénieu...
# 3  un profil ba orienté data est recherché ; il e...
# 4  pré-requis:bac+5 ecole d'ingénieur ou équivale...
#
#                                          description                   ville  \
# 0  *** data analyst qlik sense - mission freelanc...   île-de-france, france
# 1  missions : - participer activement à l'équipe ...   île-de-france, france
# 2  qui sommes-nous ? chez amd blue, l'innovation ...           paris, france
# 3  le business analyst intervient comme une inter...  bagneux, île-de-france
# 4  nous recherchons plusieurs data analysts pour ...  puteaux, île-de-france
#
#                                                 lien
# 0  https://www.free-work.com/fr/tech-it/analyste/...
# 1  https://www.free-work.com/fr/tech-it/analyste/...
# 2  https://www.free-work.com/fr/tech-it/analyste/...
# 3  https://www.free-work.com/fr/tech-it/analyste/...
# 4  https://www.free-work.com/fr/tech-it/analyste/...
